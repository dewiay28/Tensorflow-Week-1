# %% [markdown]
# The Hello World of Deep Learning with Neural Networks

# %% [markdown]
# #IMPORT

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# - importing TensorFlow and calling it tf for convention and ease of use.
# - import a library called numpy which helps to represent data as arrays easily and to optimize numerical operations.
# - The framework you will use to build a neural network as a sequence of layers is called keras so you will import that too

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# #Define and Compile the Neural Network

# %%
#build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
#compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# use mean squared error for the loss and stochastic gradient descent for the optimizer

# %%
#declare model inputs and outputs for training
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# #Training the Neural Network

# %%
#train model
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 557ms/step - loss: 44.2012
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 35.1470
# Epoch 3/500
# 1/1 [==============================] - 0s 13ms/step - loss: 28.0160
# Epoch 4/500
# 1/1 [==============================] - 0s 14ms/step - loss: 22.3982
# Epoch 5/500
# 1/1 [==============================] - 0s 14ms/step - loss: 17.9710
# Epoch 6/500
# 1/1 [==============================] - 0s 12ms/step - loss: 14.4808
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 11.7278
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 9.5550
# Epoch 9/500
# 1/1 [==============================] - 0s 11ms/step - loss: 7.8388
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 6.4820
# Epoch 11/500
# 1/1 [==============================] - 0s 11ms/step - loss: 5.4081
# Epoch 12/500
# ...

# %% [markdown]
# making a guess, measuring how good or bad it is (aka the loss), using the optimizer to make another guess etc. It will do it for the number of epochs you specify.

# %%
#make a prediction
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 161ms/step
# [[18.977158]]

# %% [markdown]
# it calculated that there is a very high probability that the relationship between x and y is y=2x-1, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 19, but not necessarily 19.
